# %% [markdown]
# The following script consists of a Python version of Andrew Ng Stanford Course 'Machine Learning' taught on the Coursera Platform
# Note: All exercise data and structure are credited to Stanford University
#
# **Caveat:** Contrary to the modularity presented in Octave scripts and as I'm using Jupyter Notebooks for educational purposes we will implement the functions on the same notebook where we will call them

# %% [markdown]
# # Exercise 1 - Load and Estimate Dataset Statistics

# %%
# Import numpy libraries to deal with matrixes and vectors
import numpy as np
# Import pandas do read data files
import pandas as pd
# Import matplotlib to plot data
import matplotlib.pyplot as plt

# Import math 
import math 

# Import scipy optimization function
from scipy import optimize, io
from scipy.ndimage import rotate

# Matplotlib notebook property
# %matplotlib inline

# %% [markdown]
# Anomaly detection is widely used across several machine problems to estimate the probability of some example not fitting some kind of "distribution".
# <br>
# <br>
# In our example we are going to evaluate the possibility of some examples not belonging to a gaussian distribution and therefore considering anomalous.

# %%
# Read the datasets 
X = io.loadmat('ex8data1.mat')['X']
X_val = io.loadmat('ex8data1.mat')['Xval']
y_val = io.loadmat('ex8data1.mat')['yval']

# %% [markdown]
# Our data consists of throughput and latency data from several servers. We want to estimate which servers deviate more the norm, and we know that the data is approximately normally distributed.

# %%
def plotData(
    X: np.array,
    X_flag = True
) -> None:
    '''
    Computes scatter plot of original data
    with X1 and X2 columns in each axis.
    
    Args:
        X(np.array): Array of original features.
    Returns:
        None        
    '''
    if X_flag:
        plt.scatter(X[:,0], X[:,1], marker='x', facecolors='blue')
    else:
        plt.scatter(X[:,0], X[:,1], marker='x', facecolors='red')
        
    plt.xlabel('Latency (ms)')
    plt.ylabel('Througput (mb/s)')

# %%
plotData(X)

# %% [markdown]
# A huge cloud of points are concentrated in the center of our graph. By looking at it we can see that there are some examples that don't seem the fit the distribution of our data.

# %% [markdown]
# # Exercise 2 - Estimating Gaussian

# %% [markdown]
# We can measure if the points belong to the distribution by looking at the probability of each example belonging to the distribution given a mean and a standard deviation:

# %% [markdown]
# <img src="assets/gaussianprob.png">

# %% [markdown]
# First, let's compute the statistics for each variable on our dataset:

# %%
def estimateGaussian(
    X: np.array
) -> np.array:
    '''
    Computes mean and standard deviation
    for each feature of the X array.
    
    Args:
        X(np.array): Original data.
        
    Returns:
        mean(np.array): Array of means of each ith feature.
        sigma(np.array): Array of standard deviation of 
        each ith feature.
    '''
    
    m, n = X.shape
    
    mean = np.zeros(n)
    sigma = np.zeros(n)
    
    for feature in range(n):
        
        mean[feature] = X[:,feature].sum()/m
        sigma[feature] = ((X[:,feature]-(mean[feature]))**2).sum()/m
        
    return mean.reshape(mean.shape[0], 1), sigma.reshape(sigma.shape[0], 1)

# %%
mu, sigma = estimateGaussian(X)

# %% [markdown]
# Now that we have obtained the mu and sigma parameters from the data, we can estimate the density for each point.

# %%
def multivariateGaussian(
    X: np.array, 
    mu: np.array,
    sigma2: np.array
) -> np.array:
    '''
    Estimates density using mu and sigma 
    parameters for each example in the 
    X dataset.
    
    Args:
        X(np.array): Original data.
        mu(np.array): Array of means.
        sigma2(np.array): Array of standard
        deviations.
    
    Returns:
        p(np.array): Density of each point
        using parameters mu and sigma
    '''
    
    # Define number of variables
    k = len(mu)
    
    
    # Create diagonal matrix based on sigma
    if sigma2.shape[0] == 1 or sigma2.shape[1] == 1:
        sigma2 = np.diag(sigma2.flatten())    
    
    # Compute density - based on user dibgerge implementation
    X = X - mu.T
    p_a = (2 * np.pi) ** (- k / 2) * np.linalg.det(sigma2) ** (-0.5)
    p_b = np.exp(-0.5 * np.sum(np.dot(X, np.linalg.pinv(sigma2)) * X, axis=1))
    
    p = p_a*p_b
    
    return p

# %%
p = multivariateGaussian(X, mu, sigma)

# %%
def visualizeFit(
    X: np.array,
    mu: np.array,
    sigma: np.array,
    X_flag: bool
) -> np.array:
    
    '''
    Visualize fit and contour 
    of distribution based on standard deviation
    
    Args:
        X(np.array): Original data.
        mu(np.array): Array of means.
        sigma(np.array): Array of standard
        deviations.
    '''
    X1, X2 = np.meshgrid(np.arange(0, 35.5, 0.5), np.arange(0, 35.5, 0.5))
    
    stacked = np.stack([X1.ravel(), X2.ravel()], axis=1)
    
    # Construct Z 
    Z = multivariateGaussian(stacked, mu, sigma)
    Z = Z.reshape(X1.shape)
    
    # Plot original data
    if X_flag:
        plotData(X)
    else:
        plotData(X, X_flag)
    
    # Plot contour using mesh grid X1 and X2
    plt.contour(X1, X2, Z, levels=10**(np.arange(-20., 1, 3)), zorder=100)

# %%
visualizeFit(X, mu, sigma, True)

# %% [markdown]
# Some of these values may be anomalies regarding the distribution of the dataset. We can use an epsilon as a threshold to consider which examples that lie outside of the yellow boundary will be considered outliers. Let's use the validation set with labeled examples (of what is an anomaly and what isn't) to understand this:

# %%
pval = multivariateGaussian(X_val, mu, sigma);

# %%
print('There are {} anomalies in the validation dataset.'.format(y_val.sum()))
# Out:
# There are 9 anomalies in the validation dataset.

# %% [markdown]
# Let's see which are the anomalies:

# %%
visualizeFit(X_val[(y_val==0).ravel(),:], mu, sigma, True)
visualizeFit(X_val[(y_val==1).ravel(),:], mu, sigma, False)

# %% [markdown]
# We see that most anomalies lie outside of the boundaries of the first countour lines. We will use an F-score to choose the best threshold that better maximizes precision and recall. Fscore, precision and recall are computed as follows:

# %% [markdown]
# <img src="assets/fscore.jpg">

# %% [markdown]
# <img src="assets/precrecall.jpg">

# %% [markdown]
# # Exercise 3 - Selecting the best threshold

# %%
def selectThreshold(
    yval: np.array,
    pval: np.array
) -> [float, float]:
    
    '''
    Selects best solution based 
    on f-score to filter anomalies 
    from the pval array using the density
    p.
    
    Args:
        yval(np.array): Target values of y
        pval(np.array): Probability density
        values for each y.
    
    Returns:
        bestEpsilon(float): Best epsilon threshold.
        bestF1(float): Best f1 score found by 
        the algorithm.
    '''
    
    bestEpsilon = 0
    bestF1 = 0
    F1 = 0
    
    # Define stepsize to iterate
    stepsize = (max(pval)-min(pval))/1000
    
    for epsilon in np.arange(min(pval), max(pval), stepsize):
        
        # Define prediction 
        pred = (pval < epsilon)
        
        # False Positives
        fp = pred[(pred==1) & (yval==0).ravel(),].sum()
        
        # True Positives
        tp = pred[(pred==1) & (yval==1).ravel(),].sum()
        
        # False Negatives
        fn = pred[(pred==0) & (yval==1).ravel(),].sum()
        
        # Precision
        prec = tp / (tp+fp)
        
        # Recall
        rec = tp / (tp+fn)
        
        F1 = (2*prec*rec)/(prec+rec)
        # Update epsilon and F1 if we have a better result
        if F1 > bestF1:
            bestF1 = F1
            bestEpsilon = epsilon
        
    return bestF1, bestEpsilon

# %%
F1, epsilon = selectThreshold(y_val, pval)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in long_scalars
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: RuntimeWarning: invalid value encountered in long_scalars

# %%
print('Our F-score is {} and our epsilon is {}'.format(F1, epsilon))
# Out:
# Our F-score is 1.0 and our epsilon is 8.990852779269495e-05

# %% [markdown]
# Let's find the values that have a density lower than our epsilon:

# %%
outliers = X_val[(pval < epsilon).ravel()]

# %%
visualizeFit(X_val[(y_val==0).ravel(),:], mu, sigma, True)
visualizeFit(outliers, mu, sigma, False)

# %% [markdown]
# The red crosses were the observations where the density was lower than our best epsilon - these are the observations that are least likely to belong to our distribution.

# %% [markdown]
# # Exercise 4 - Multidimensional Outliers

# %% [markdown]
# We will now do the same for a dataset with more dimensions.

# %%
# Read the datasets 
X_2 = io.loadmat('ex8data2.mat')['X']
X_val_2 = io.loadmat('ex8data2.mat')['Xval']
y_val_2 = io.loadmat('ex8data2.mat')['yval']

# %%
mu2, sigma2 = estimateGaussian(X_2)

# %%
p_2 = multivariateGaussian(X_2, mu2, sigma2)

# %%
p_2_val = multivariateGaussian(X_val_2, mu2, sigma2)

# %%
F1_2, epsilon_2 = selectThreshold(y_val_2, p_2_val)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in long_scalars
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: RuntimeWarning: invalid value encountered in long_scalars

# %%
F1_2
# Out:
# 0.6666666666666666
